# %%
import numpy as np
import matplotlib.pyplot as plt

def evaluate_spline(x, y, h, M, x_eval):
    n = len(x)
    y_eval = np.zeros(len(x_eval))
    for k in range(len(x_eval)):
        for i in range(n - 1):
            if x[i] <= x_eval[k] <= x[i + 1]:
                dx = x_eval[k] - x[i]
                a_i = y[i]
                b_i = (y[i+1] - y[i]) / h[i] - h[i] * (2 * M[i] + M[i+1]) / 6
                c_i = M[i] / 2
                d_i = (M[i+1] - M[i]) / (6 * h[i])
                y_eval[k] = a_i + b_i * dx + c_i * dx**2 + d_i * dx**3
                break
    return y_eval

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

n = len(x)
h = np.diff(x)

A = np.zeros(n - 2)
B = np.zeros(n - 2)
C = np.zeros(n - 2)
D = np.zeros(n - 2)

for i in range(1, n - 1):
    A[i - 1] = h[i - 1]
    B[i - 1] = 2 * (h[i - 1] + h[i])
    C[i - 1] = h[i]
    D[i - 1] = 6 * ((y[i + 1] - y[i]) / h[i] - (y[i] - y[i - 1]) / h[i - 1])
    
nn = len(B)

for i in range(1, nn):
    w = A[i] / B[i - 1]
    B[i] = B[i] - w * C[i - 1]
    D[i] = D[i] - w * D[i - 1]
    
M_inner = np.zeros(nn)

M_inner[-1] = D[-1] / B[-1]

for i in range(nn - 2, -1, -1):
    M_inner[i] = (D[i] - C[i] * M_inner[i + 1]) / B[i]
    
M = np.zeros(len(x))

for i in range(len(M_inner)):
    M[i + 1] = M_inner[i]
    
x_eval = np.linspace(x[0], x[-1], 200)
y_eval = evaluate_spline(x, y, h, M, x_eval)

plt.plot(x_eval, y_eval, label='Cubic Spline')
plt.plot(x, y, "o", label='Data Points')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
