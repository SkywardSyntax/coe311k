# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.linspace(0,2*np.pi,99)
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))
plt.subplot(2,2,3)
plt.plot(x, np.tan(x))
plt.subplot(2,2,4)
plt.plot(x, np.arcsin(x))
plt.show()
# Out:
# <ipython-input-8-aa306bf41b1f>:12: RuntimeWarning: invalid value encountered in arcsin
#   plt.plot(x, np.arcsin(x))

# %%
x = np.random.rand(100)
y = np.random.rand(100)
size = np.random.rand(100)*100
color = np.random.rand(100)
plt.scatter(x,y,size,color)
plt.colorbar()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def f1(x,y):
    return(x**2 + y**2)

x = np.linspace(-20,20,2000)
y = np.linspace(-20,20,2000)
X, Y = np.meshgrid(x,y)
Z = f1(X,Y)

fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(45, 45)
