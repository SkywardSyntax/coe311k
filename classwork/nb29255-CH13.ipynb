# %%
import numpy as np
import time
import matplotlib.pyplot as plt

def naive_matrix_multiplication(A, B):
    n = len(A)
    C = [[0] * n for _ in range(n)]
    for i in range(n):
        for j in range(n):
            for k in range(n):
                C[i][j] += A[i][k] * B[k][j]
    return C

sizes = [3, 6, 12, 24, 48, 96, 192, 384]
naive_times = []
numpy_times = []

for s in sizes:
    A = np.random.rand(s, s)
    B = np.random.rand(s, s)

    start = time.time()
    naive_matrix_multiplication(A.tolist(), B.tolist())
    naive_times.append(time.time() - start)

    start = time.time()
    np.dot(A, B)
    numpy_times.append(time.time() - start)

plt.plot(sizes, naive_times, label='Naive')
plt.plot(sizes, numpy_times, label='NumPy')
plt.xlabel('Matrix Size')
plt.ylabel('Time (s)')
plt.title('Naive vs NumPy Matrix Multiplication')
plt.legend()
plt.show()

# %%
The numpy version seems to be running at roughly constant time (at this scale, especially when compared to the naive version). 
Needless to say the numpy version seems significantly more optimized than our naive code.
# Out:
#   Cell In[6], line 1
#     The numpy version seems to be running at roughly constant time (at this scale, especially when compared to the naive version). Needless to say the numpy version seems significantly more optimized than our naive code
#         ^
# SyntaxError: invalid syntax
