# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters

k = 10.0        # Constant in the equation (e.g., spring constant)
h = np.arange(0.01, 0.04, 0.01)
h = np.concatenate((h, np.array([0.05])))
h = np.concatenate((h, np.linspace(0.1, 0.3, 3)))
h = np.concatenate((h, np.array([0.5])))

x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx

# Create arrays to store x, y, and v values
for step in range(len(h)):
    x_values = np.arange(x_start, x_end + h[step], h[step])
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))

    # Set initial conditions

    y_values[0] = y_0
    v_values[0] = v_0

    

    # Euler's Method loop

    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        # Update equations
        y_values[i] = y_n + h[0] * v_n
        v_values[i] = v_n + h[0] * (-k * y_n)

    

    # Plot the results
    if (step == 0):
        plt.figure(figsize=(10, 5))
    plt.plot(x_values, y_values, label="Position y(x) @ " + str(h[step]))
    plt.plot(x_values, v_values, label="Velocity v(x) @ " + str(h[step]), linestyle='--')

plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# If I look at k=10, with a small step size it looks like the peaks and troughs of the sin wave keep getting bigger. This is a general trend I see across all step sizes. So if we keep integrating long enough we should see more error in Forward Euler. If I make the k to be 100, it becomes immediately obvious that Forward Euler won't work, and we start seeing wild oscillatory errors for larger step sizes.
