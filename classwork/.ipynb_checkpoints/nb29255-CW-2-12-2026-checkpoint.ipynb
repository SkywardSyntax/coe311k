# %%
import numpy as np

# %%
v1 = np.array([1,2,3])
v2 = np.array([4,5,6])
m1 = np.vstack([v1,v2])
v3 = m1@v1
print(v3)
# Out:
# [14 32]

# %%
w
# Out:
#   [3. 1.]
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
